# %%
import os 
import rampwf as rw
import ramphy as rh

# %%
rh.actions.select_top_hyperopt(ramp_kit_dir='/home/gpaolo/nas/ramp-kits/kaggle_heat_flux_fi_v1_1_n1', submission='lgbm', top_n=1, fold_idxs=range(900, 931))
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 0.07342731280187961
# {'selected_submissions': ['lgbm_hyperopt_b77801d68c'],
#  'score_cutoff': 0.07342731280187961}

# %%
rh.actions.select_top_hyperopt(ramp_kit_dir='/home/gpaolo/nas/ramp-kits/kaggle_heat_flux_fi_v1_1_n1', submission='catboost', fold_idxs=range(900, 931), top_n=1)
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 0.0750205627321918
# {'selected_submissions': ['catboost_hyperopt_5c3579dcf3'],
#  'score_cutoff': 0.0750205627321918}

# %%
rh.actions.select_top_hyperopt(ramp_kit_dir='/home/gpaolo/nas/ramp-kits/kaggle_heat_flux_fi_v1_1_n1', submission='xgboost', fold_idxs=range(900, 931), top_n=1)
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 0.07542022416620983
# {'selected_submissions': ['xgboost_hyperopt_77a5e909df'],
#  'score_cutoff': 0.07542022416620983}
