# %%
import os 
import rampwf as rw
import ramphy as rh

# %%
rh.actions.select_top_hyperopt(ramp_kit_dir='/home/gpaolo/nas/ramp-kits/kaggle_blueberry_v1_1_n1', submission='lgbm', top_n=1, fold_idxs=range(900, 931))
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 339.819331947537
# {'selected_submissions': ['lgbm_hyperopt_053866799e'],
#  'score_cutoff': 339.819331947537}

# %%
rh.actions.select_top_hyperopt(ramp_kit_dir='/home/gpaolo/nas/ramp-kits/kaggle_blueberry_v1_1_n1', submission='catboost', fold_idxs=range(900, 931), top_n=1)
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 339.9125938797693
# {'selected_submissions': ['catboost_hyperopt_569b6d2fc7'],
#  'score_cutoff': 339.9125938797693}

# %%
rh.actions.select_top_hyperopt(ramp_kit_dir='/home/gpaolo/nas/ramp-kits/kaggle_blueberry_v1_1_n1', submission='xgboost', fold_idxs=range(900, 931), top_n=1)
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 344.2944636242046
# {'selected_submissions': ['xgboost_hyperopt_a473108fb4'],
#  'score_cutoff': 344.2944636242046}
